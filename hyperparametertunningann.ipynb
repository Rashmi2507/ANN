# %%
import sys

# 1. Force reinstall matched ecosystem versions
# !{sys.executable} -m pip install --upgrade --force-reinstall tensorflow scikeras scikit-learn
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# Collecting scikeras
#   Using cached scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting packaging (from tensorflow)
#   Downloading packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow)
#   Downloading protobuf-7.35.0-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow)
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting setuptools (from tensorflow)
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting six>=1.12.0 (from tensorflow)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting typing_extensions>=3.6.6 (from tensorflow)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.2.1-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Using cached grpcio-1.80.0-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Collecting keras>=3.12.0 (from tensorflow)
#   Using cached keras-3.14.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting numpy>=1.26.0 (from tensorflow)
#   Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp311-cp311-win_amd64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow)
#   Using cached charset_normalizer-3.4.7-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow)
#   Downloading idna-3.16-py3-none-any.whl.metadata (6.4 kB)
# Collecting urllib3<3,>=1.26 (from requests<3,>=2.21.0->tensorflow)
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests<3,>=2.21.0->tensorflow)
#   Downloading certifi-2026.5.20-py3-none-any.whl.metadata (2.5 kB)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.47.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.12.0->tensorflow)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.12.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.12.0->tensorflow)
#   Using cached optree-0.19.1-cp311-cp311-win_amd64.whl.metadata (32 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.12.0->tensorflow)
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich->keras>=3.12.0->tensorflow)
#   Using cached pygments-2.20.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.21.0-cp311-cp311-win_amd64.whl (350.8 MB)
#    ---------------------------------------- 0.0/350.8 MB ? eta -:--:--
#    ---------------------------------------- 2.9/350.8 MB 15.2 MB/s eta 0:00:23
#     --------------------------------------- 6.0/350.8 MB 14.7 MB/s eta 0:00:24
#    - -------------------------------------- 9.2/350.8 MB 14.6 MB/s eta 0:00:24
#    - -------------------------------------- 12.3/350.8 MB 14.6 MB/s eta 0:00:24
#    - -------------------------------------- 15.5/350.8 MB 14.5 MB/s eta 0:00:24
#    -- ------------------------------------- 18.6/350.8 MB 14.7 MB/s eta 0:00:23
#    -- ------------------------------------- 21.8/350.8 MB 14.6 MB/s eta 0:00:23
#    -- ------------------------------------- 24.9/350.8 MB 14.6 MB/s eta 0:00:23
#    --- ------------------------------------ 28.0/350.8 MB 14.6 MB/s eta 0:00:23
#    --- ------------------------------------ 31.2/350.8 MB 14.6 MB/s eta 0:00:22
#    --- ------------------------------------ 34.3/350.8 MB 14.5 MB/s eta 0:00:22
#    ---- ----------------------------------- 37.5/350.8 MB 14.6 MB/s eta 0:00:22
#    ---- ----------------------------------- 40.4/350.8 MB 14.6 MB/s eta 0:00:22
#    ---- ----------------------------------- 43.8/350.8 MB 14.6 MB/s eta 0:00:22
#    ----- ---------------------------------- 46.9/350.8 MB 14.6 MB/s eta 0:00:21
#    ----- ---------------------------------- 50.1/350.8 MB 14.6 MB/s eta 0:00:21
#    ------ --------------------------------- 53.2/350.8 MB 14.6 MB/s eta 0:00:21
#    ------ --------------------------------- 56.4/350.8 MB 14.6 MB/s eta 0:00:21
#    -------------------------------- ------ 292.8/350.8 MB 14.5 MB/s eta 0:00:04
#    -------------------------------- ------ 296.0/350.8 MB 14.5 MB/s eta 0:00:04
#    --------------------------------- ----- 298.8/350.8 MB 14.5 MB/s eta 0:00:04
#    --------------------------------- ----- 302.0/350.8 MB 14.5 MB/s eta 0:00:04
#    --------------------------------- ----- 305.1/350.8 MB 14.5 MB/s eta 0:00:04
#    ---------------------------------- ---- 308.3/350.8 MB 14.5 MB/s eta 0:00:03
#    ---------------------------------- ---- 311.7/350.8 MB 14.5 MB/s eta 0:00:03
#    ---------------------------------- ---- 314.8/350.8 MB 14.5 MB/s eta 0:00:03
#    ----------------------------------- --- 317.7/350.8 MB 14.5 MB/s eta 0:00:03
#    ----------------------------------- --- 321.1/350.8 MB 14.5 MB/s eta 0:00:03
#    ------------------------------------ -- 324.0/350.8 MB 14.5 MB/s eta 0:00:02
#    ------------------------------------ -- 327.4/350.8 MB 14.5 MB/s eta 0:00:02
#    ------------------------------------ -- 330.3/350.8 MB 14.5 MB/s eta 0:00:02
#    ------------------------------------- - 333.7/350.8 MB 14.5 MB/s eta 0:00:02
#    ------------------------------------- - 336.6/350.8 MB 14.5 MB/s eta 0:00:01
#    ------------------------------------- - 339.7/350.8 MB 14.5 MB/s eta 0:00:01
#    --------------------------------------  342.9/350.8 MB 14.5 MB/s eta 0:00:01
#    --------------------------------------  346.0/350.8 MB 14.5 MB/s eta 0:00:01
#    --------------------------------------  349.2/350.8 MB 14.5 MB/s eta 0:00:01
#    --------------------------------------  350.7/350.8 MB 14.5 MB/s eta 0:00:01
#    --------------------------------------  350.7/350.8 MB 14.5 MB/s eta 0:00:01
#    --------------------------------------  350.7/350.8 MB 14.5 MB/s eta 0:00:01
#    --------------------------------------  350.7/350.8 MB 14.5 MB/s eta 0:00:01
#    --------------------------------------  350.7/350.8 MB 14.5 MB/s eta 0:00:01
#    ---------------------------------------- 350.8/350.8 MB 13.7 MB/s  0:00:25
# Using cached grpcio-1.80.0-cp311-cp311-win_amd64.whl (4.9 MB)
# Downloading h5py-3.14.0-cp311-cp311-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ------------------------------------ --- 2.6/2.9 MB 15.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 11.9 MB/s  0:00:00
# Downloading ml_dtypes-0.5.4-cp311-cp311-win_amd64.whl (210 kB)
# Downloading protobuf-7.35.0-cp310-abi3-win_amd64.whl (439 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Using cached charset_normalizer-3.4.7-cp311-cp311-win_amd64.whl (159 kB)
# Downloading idna-3.16-py3-none-any.whl (74 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Using cached scikeras-0.13.0-py3-none-any.whl (26 kB)
# Using cached scikit_learn-1.8.0-cp311-cp311-win_amd64.whl (8.1 MB)
# Using cached absl_py-2.4.0-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading wheel-0.47.0-py3-none-any.whl (32 kB)
# Downloading certifi-2026.5.20-py3-none-any.whl (134 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached keras-3.14.1-py3-none-any.whl (1.6 MB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl (12.6 MB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading packaging-26.2-py3-none-any.whl (100 kB)
# Using cached scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
# Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading wrapt-2.2.1-cp311-cp311-win_amd64.whl (80 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Using cached optree-0.19.1-cp311-cp311-win_amd64.whl (337 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached pygments-2.20.0-py3-none-any.whl (1.2 MB)
# Using cached markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, urllib3, typing_extensions, threadpoolctl, termcolor, six, setuptools, pygments, protobuf, packaging, opt_einsum, numpy, mdurl, joblib, idna, gast, charset_normalizer, certifi, absl-py, wheel, scipy, requests, optree, ml_dtypes, markdown-it-py, h5py, grpcio, google_pasta, scikit-learn, rich, astunparse, keras, tensorflow, scikeras
#
#   Attempting uninstall: namex
#
#     Found existing installation: namex 0.1.0
#
#     Uninstalling namex-0.1.0:
#
#       Successfully uninstalled namex-0.1.0
#
#   Attempting uninstall: libclang
#
#     Found existing installation: libclang 18.1.1
#
#     Uninstalling libclang-18.1.1:
#
#    - --------------------------------------  1/37 [libclang]
#       Successfully uninstalled libclang-18.1.1
#    - --------------------------------------  1/37 [libclang]
#    - --------------------------------------  1/37 [libclang]
#    - --------------------------------------  1/37 [libclang]
#    - --------------------------------------  1/37 [libclang]
#    - --------------------------------------  1/37 [libclang]
#   Attempting uninstall: flatbuffers
#    - --------------------------------------  1/37 [libclang]
#     Found existing installation: flatbuffers 25.12.19
#    - --------------------------------------  1/37 [libclang]
#     Uninstalling flatbuffers-25.12.19:
#    - --------------------------------------  1/37 [libclang]
#       Successfully uninstalled flatbuffers-25.12.19
#    - --------------------------------------  1/37 [libclang]
#    -- -------------------------------------  2/37 [flatbuffers]
#    -- -------------------------------------  2/37 [flatbuffers]
#   Attempting uninstall: wrapt
#    -- -------------------------------------  2/37 [flatbuffers]
#     Found existing installation: wrapt 1.14.2
#    -- -------------------------------------  2/37 [flatbuffers]
#     Uninstalling wrapt-1.14.2:
#    -- -------------------------------------  2/37 [flatbuffers]
#       Successfully uninstalled wrapt-1.14.2
#    -- -------------------------------------  2/37 [flatbuffers]
#    --- ------------------------------------  3/37 [wrapt]
#    --- ------------------------------------  3/37 [wrapt]
#   Attempting uninstall: urllib3
#    --- ------------------------------------  3/37 [wrapt]
#     Found existing installation: urllib3 2.7.0
#    --- ------------------------------------  3/37 [wrapt]
#     Uninstalling urllib3-2.7.0:
#    --- ------------------------------------  3/37 [wrapt]
#       Successfully uninstalled urllib3-2.7.0
#    --- ------------------------------------  3/37 [wrapt]
#    ---- -----------------------------------  4/37 [urllib3]
#    ---- -----------------------------------  4/37 [urllib3]
#    ---- -----------------------------------  4/37 [urllib3]
#    ---- -----------------------------------  4/37 [urllib3]
#    ---- -----------------------------------  4/37 [urllib3]
#   Attempting uninstall: typing_extensions
#    ---- -----------------------------------  4/37 [urllib3]
#     Found existing installation: typing_extensions 4.15.0
#    ---- -----------------------------------  4/37 [urllib3]
#     Uninstalling typing_extensions-4.15.0:
#    ---- -----------------------------------  4/37 [urllib3]
#    ----- ----------------------------------  5/37 [typing_extensions]
#    ----- ----------------------------------  5/37 [typing_extensions]
#    ----- ----------------------------------  5/37 [typing_extensions]
#    ----- ----------------------------------  5/37 [typing_extensions]
#    ----- ----------------------------------  5/37 [typing_extensions]
#    ----- ----------------------------------  5/37 [typing_extensions]
#       Successfully uninstalled typing_extensions-4.15.0
#    ----- ----------------------------------  5/37 [typing_extensions]
#   Attempting uninstall: threadpoolctl
#    ----- ----------------------------------  5/37 [typing_extensions]
#     Found existing installation: threadpoolctl 3.6.0
#    ----- ----------------------------------  5/37 [typing_extensions]
#     Uninstalling threadpoolctl-3.6.0:
#    ----- ----------------------------------  5/37 [typing_extensions]
#    ------ ---------------------------------  6/37 [threadpoolctl]
#    ------ ---------------------------------  6/37 [threadpoolctl]
#    ------ ---------------------------------  6/37 [threadpoolctl]
#    ------ ---------------------------------  6/37 [threadpoolctl]
#    ------ ---------------------------------  6/37 [threadpoolctl]
#    ------ ---------------------------------  6/37 [threadpoolctl]
#       Successfully uninstalled threadpoolctl-3.6.0
#    ------ ---------------------------------  6/37 [threadpoolctl]
#    ------ ---------------------------------  6/37 [threadpoolctl]
#   Attempting uninstall: termcolor
#    ------ ---------------------------------  6/37 [threadpoolctl]
#     Found existing installation: termcolor 3.3.0
#    ------ ---------------------------------  6/37 [threadpoolctl]
#     Uninstalling termcolor-3.3.0:
#    ------ ---------------------------------  6/37 [threadpoolctl]
#       Successfully uninstalled termcolor-3.3.0
#    ------ ---------------------------------  6/37 [threadpoolctl]
#    ------- --------------------------------  7/37 [termcolor]
#   Attempting uninstall: six
#    ------- --------------------------------  7/37 [termcolor]
#     Found existing installation: six 1.17.0
#    ------- --------------------------------  7/37 [termcolor]
#     Uninstalling six-1.17.0:
#    ------- --------------------------------  7/37 [termcolor]
#    -------- -------------------------------  8/37 [six]
#    -------- -------------------------------  8/37 [six]
#    -------- -------------------------------  8/37 [six]
#    -------- -------------------------------  8/37 [six]
#    -------- -------------------------------  8/37 [six]
#    -------- -------------------------------  8/37 [six]
#    -------- -------------------------------  8/37 [six]
#    -------- -------------------------------  8/37 [six]
#       Successfully uninstalled six-1.17.0
#    -------- -------------------------------  8/37 [six]
#   Attempting uninstall: setuptools
#    -------- -------------------------------  8/37 [six]
#     Found existing installation: setuptools 80.10.2
#    -------- -------------------------------  8/37 [six]
#     Uninstalling setuptools-80.10.2:
#    -------- -------------------------------  8/37 [six]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#       Successfully uninstalled setuptools-80.10.2
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#    --------- ------------------------------  9/37 [setuptools]
#   Attempting uninstall: pygments
#    --------- ------------------------------  9/37 [setuptools]
#     Found existing installation: Pygments 2.20.0
#    --------- ------------------------------  9/37 [setuptools]
#     Uninstalling Pygments-2.20.0:
#    --------- ------------------------------  9/37 [setuptools]
#       Successfully uninstalled Pygments-2.20.0
#    --------- ------------------------------  9/37 [setuptools]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#    ---------- ----------------------------- 10/37 [pygments]
#   Attempting uninstall: protobuf
#    ---------- ----------------------------- 10/37 [pygments]
#     Found existing installation: protobuf 4.25.9
#    ---------- ----------------------------- 10/37 [pygments]
#     Uninstalling protobuf-4.25.9:
#    ---------- ----------------------------- 10/37 [pygments]
#       Successfully uninstalled protobuf-4.25.9
#    ---------- ----------------------------- 10/37 [pygments]
#    ----------- ---------------------------- 11/37 [protobuf]
#    ----------- ---------------------------- 11/37 [protobuf]
#    ----------- ---------------------------- 11/37 [protobuf]
#    ----------- ---------------------------- 11/37 [protobuf]
#    ----------- ---------------------------- 11/37 [protobuf]
#    ----------- ---------------------------- 11/37 [protobuf]
#    ----------- ---------------------------- 11/37 [protobuf]
#   Attempting uninstall: packaging
#    ----------- ---------------------------- 11/37 [protobuf]
#     Found existing installation: packaging 26.0
#    ----------- ---------------------------- 11/37 [protobuf]
#     Uninstalling packaging-26.0:
#    ----------- ---------------------------- 11/37 [protobuf]
#       Successfully uninstalled packaging-26.0
#    ----------- ---------------------------- 11/37 [protobuf]
#    ------------ --------------------------- 12/37 [packaging]
#    ------------ --------------------------- 12/37 [packaging]
#    ------------ --------------------------- 12/37 [packaging]
#   Attempting uninstall: opt_einsum
#    ------------ --------------------------- 12/37 [packaging]
#     Found existing installation: opt_einsum 3.4.0
#    ------------ --------------------------- 12/37 [packaging]
#     Uninstalling opt_einsum-3.4.0:
#    ------------ --------------------------- 12/37 [packaging]
#       Successfully uninstalled opt_einsum-3.4.0
#    ------------ --------------------------- 12/37 [packaging]
#    -------------- ------------------------- 13/37 [opt_einsum]
#    -------------- ------------------------- 13/37 [opt_einsum]
#   Attempting uninstall: numpy
#    -------------- ------------------------- 13/37 [opt_einsum]
#     Found existing installation: numpy 1.26.4
#    -------------- ------------------------- 13/37 [opt_einsum]
#    --------------- ------------------------ 14/37 [numpy]
#     Uninstalling numpy-1.26.4:
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#       Successfully uninstalled numpy-1.26.4
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#    --------------- ------------------------ 14/37 [numpy]
#   Attempting uninstall: mdurl
#    --------------- ------------------------ 14/37 [numpy]
#     Found existing installation: mdurl 0.1.2
#    --------------- ------------------------ 14/37 [numpy]
#     Uninstalling mdurl-0.1.2:
#    --------------- ------------------------ 14/37 [numpy]
#       Successfully uninstalled mdurl-0.1.2
#    --------------- ------------------------ 14/37 [numpy]
#    ---------------- ----------------------- 15/37 [mdurl]
#   Attempting uninstall: joblib
#    ---------------- ----------------------- 15/37 [mdurl]
#     Found existing installation: joblib 1.5.3
#    ---------------- ----------------------- 15/37 [mdurl]
#     Uninstalling joblib-1.5.3:
#    ---------------- ----------------------- 15/37 [mdurl]
#       Successfully uninstalled joblib-1.5.3
#    ---------------- ----------------------- 15/37 [mdurl]
#    ----------------- ---------------------- 16/37 [joblib]
#    ----------------- ---------------------- 16/37 [joblib]
#    ----------------- ---------------------- 16/37 [joblib]
#    ----------------- ---------------------- 16/37 [joblib]
#    ----------------- ---------------------- 16/37 [joblib]
#    ----------------- ---------------------- 16/37 [joblib]
#    ----------------- ---------------------- 16/37 [joblib]
#    ----------------- ---------------------- 16/37 [joblib]
#   Attempting uninstall: idna
#    ----------------- ---------------------- 16/37 [joblib]
#     Found existing installation: idna 3.15
#    ----------------- ---------------------- 16/37 [joblib]
#    ------------------ --------------------- 17/37 [idna]
#     Uninstalling idna-3.15:
#    ------------------ --------------------- 17/37 [idna]
#       Successfully uninstalled idna-3.15
#    ------------------ --------------------- 17/37 [idna]
#    ------------------ --------------------- 17/37 [idna]
#   Attempting uninstall: gast
#    ------------------ --------------------- 17/37 [idna]
#     Found existing installation: gast 0.7.0
#    ------------------ --------------------- 17/37 [idna]
#     Uninstalling gast-0.7.0:
#    ------------------ --------------------- 17/37 [idna]
#       Successfully uninstalled gast-0.7.0
#    ------------------ --------------------- 17/37 [idna]
#    ------------------- -------------------- 18/37 [gast]
#    ------------------- -------------------- 18/37 [gast]
#    ------------------- -------------------- 18/37 [gast]
#   Attempting uninstall: charset_normalizer
#    ------------------- -------------------- 18/37 [gast]
#     Found existing installation: charset-normalizer 3.4.7
#    ------------------- -------------------- 18/37 [gast]
#     Uninstalling charset-normalizer-3.4.7:
#    ------------------- -------------------- 18/37 [gast]
#    -------------------- ------------------- 19/37 [charset_normalizer]
#    -------------------- ------------------- 19/37 [charset_normalizer]
#    -------------------- ------------------- 19/37 [charset_normalizer]
#    -------------------- ------------------- 19/37 [charset_normalizer]
#    -------------------- ------------------- 19/37 [charset_normalizer]
#       Successfully uninstalled charset-normalizer-3.4.7
#    -------------------- ------------------- 19/37 [charset_normalizer]
#    -------------------- ------------------- 19/37 [charset_normalizer]
#    -------------------- ------------------- 19/37 [charset_normalizer]
#   Attempting uninstall: certifi
#    -------------------- ------------------- 19/37 [charset_normalizer]
#     Found existing installation: certifi 2026.4.22
#    -------------------- ------------------- 19/37 [charset_normalizer]
#     Uninstalling certifi-2026.4.22:
#    -------------------- ------------------- 19/37 [charset_normalizer]
#       Successfully uninstalled certifi-2026.4.22
#    -------------------- ------------------- 19/37 [charset_normalizer]
#   Attempting uninstall: absl-py
#    -------------------- ------------------- 19/37 [charset_normalizer]
#     Found existing installation: absl-py 2.3.1
#    -------------------- ------------------- 19/37 [charset_normalizer]
#    ---------------------- ----------------- 21/37 [absl-py]
#     Uninstalling absl-py-2.3.1:
#    ---------------------- ----------------- 21/37 [absl-py]
#       Successfully uninstalled absl-py-2.3.1
#    ---------------------- ----------------- 21/37 [absl-py]
#    ---------------------- ----------------- 21/37 [absl-py]
#    ---------------------- ----------------- 21/37 [absl-py]
#   Attempting uninstall: wheel
#    ---------------------- ----------------- 21/37 [absl-py]
#     Found existing installation: wheel 0.46.3
#    ---------------------- ----------------- 21/37 [absl-py]
#     Uninstalling wheel-0.46.3:
#    ---------------------- ----------------- 21/37 [absl-py]
#       Successfully uninstalled wheel-0.46.3
#    ---------------------- ----------------- 21/37 [absl-py]
#    ----------------------- ---------------- 22/37 [wheel]
#    ----------------------- ---------------- 22/37 [wheel]
#   Attempting uninstall: scipy
#    ----------------------- ---------------- 22/37 [wheel]
#     Found existing installation: scipy 1.17.1
#    ----------------------- ---------------- 22/37 [wheel]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#     Uninstalling scipy-1.17.1:
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#       Successfully uninstalled scipy-1.17.1
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------ --------------- 23/37 [scipy]
#   Attempting uninstall: requests
#    ------------------------ --------------- 23/37 [scipy]
#     Found existing installation: requests 2.34.2
#    ------------------------ --------------- 23/37 [scipy]
#     Uninstalling requests-2.34.2:
#    ------------------------ --------------- 23/37 [scipy]
#       Successfully uninstalled requests-2.34.2
#    ------------------------ --------------- 23/37 [scipy]
#    ------------------------- -------------- 24/37 [requests]
#    ------------------------- -------------- 24/37 [requests]
#    ------------------------- -------------- 24/37 [requests]
#   Attempting uninstall: optree
#    ------------------------- -------------- 24/37 [requests]
# ...
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#    ------------------------------------- -- 35/37 [tensorflow]
#   Attempting uninstall: scikeras
#    ------------------------------------- -- 35/37 [tensorflow]
#     Found existing installation: scikeras 0.13.0
#    ------------------------------------- -- 35/37 [tensorflow]
#     Uninstalling scikeras-0.13.0:
#    ------------------------------------- -- 35/37 [tensorflow]
#    -------------------------------------- - 36/37 [scikeras]
#    -------------------------------------- - 36/37 [scikeras]
#    -------------------------------------- - 36/37 [scikeras]
#    -------------------------------------- - 36/37 [scikeras]
#       Successfully uninstalled scikeras-0.13.0
#    -------------------------------------- - 36/37 [scikeras]
#    -------------------------------------- - 36/37 [scikeras]
#    ---------------------------------------- 37/37 [scikeras]
#
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 certifi-2026.5.20 charset_normalizer-3.4.7 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.80.0 h5py-3.14.0 idna-3.16 joblib-1.5.3 keras-3.14.1 libclang-18.1.1 markdown-it-py-4.2.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 numpy-2.4.4 opt_einsum-3.4.0 optree-0.19.1 packaging-26.2 protobuf-6.33.5 pygments-2.20.0 requests-2.34.2 rich-15.0.0 scikeras-0.13.0 scikit-learn-1.8.0 scipy-1.17.1 setuptools-82.0.1 six-1.17.0 tensorflow-2.21.0 termcolor-3.3.0 threadpoolctl-3.6.0 typing_extensions-4.15.0 urllib3-2.7.0 wheel-0.47.0 wrapt-2.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.14.1 which is incompatible.
# tensorflow-intel 2.15.0 requires ml-dtypes~=0.2.0, but you have ml-dtypes 0.5.4 which is incompatible.
# tensorflow-intel 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 2.4.6 which is incompatible.
# tensorflow-intel 2.15.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 7.35.0 which is incompatible.
# tensorflow-intel 2.15.0 requires wrapt<1.15,>=1.11.0, but you have wrapt 2.2.1 which is incompatible.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.pipeline import Pipeline
from scikeras.wrappers import KerasClassifier
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
def create_model(neurons=32, layers=1):
    model = Sequential()
    model.add(Dense(neurons, activation='relu', input_shape=(X_train.shape[1],)))
     
    for _ in range(layers - 1):
        model.add(Dense(neurons, activation='relu'))

    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
## Create a Keras Classifier
model = KerasClassifier(build_fn=create_model, epochs=50, batch_size=10, verbose=0)

# %%
param_grid = {
    'neurons': [16, 32, 64, 128],
    'layers': [1, 2, 3],
    'epochs': [50, 100],
    'batch_size': [10, 20]
}

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X_train, y_train)

print(f"Best: {grid_result.best_score_:.4f} using {grid_result.best_params_}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
# ----> 2 grid_result = grid.fit(X_train, y_train)
#       3
#       4 print(f"Best: {grid_result.best_score_:.4f} using {grid_result.best_params_}")
#
# NameError: name 'X_train' is not defined
